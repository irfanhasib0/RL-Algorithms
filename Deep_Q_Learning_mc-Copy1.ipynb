# %% [markdown]
# ***Importing Libraries***

# %%
import gym
import numpy as np
from collections import deque
#import random
import tensorflow
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
seed=123
np.random.seed(seed)
tensorflow.set_random_seed(seed)
# Out:
# C:\Users\irfan\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\irfan\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\irfan\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\irfan\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\irfan\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\irfan\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
Sequential=tensorflow.keras.models.Sequential
Dense=tensorflow.keras.layers.Dense 
Adam=tensorflow.keras.optimizers.Adam

# %% [raw]
# import renom as rm
# from renom_rl.discrete.double_dqn import DoubleDQN
# from renom_rl.environ.env import BaseEnv
# from renom_rl.utility.filter import EpsilonEIFilter
# from renom_rl.utility import Animation
# from renom.optimizer import Adam as AdamR
# from renom.cuda import set_cuda_active
# set_cuda_active(False)
# q_network = rm.Sequential([rm.Dense(100),
#                             rm.Relu(),
#                             rm.Dense(100),
#                             rm.Relu(),
#                             rm.Dense(act_shape)
#                          ])

# %% [markdown]
# ***Initialization of Environment***

# %%
env_to_use='MountainCar-v0'
class MountainCar():
    
    def __init__(self):
        self.env = gym.make(env_to_use) 
        self.env.seed(seed)
        self.action_shape = (self.env.action_space.n,)
        self.state_shape = self.env.observation_space.shape
        #print("Env Space : ", self.state_shape)
        #print("Action Space : ", self.action_shape)
        self.test_mode = False
    
    def reset(self):
        return self.env.reset()
    
    def sample(self):
        return self.env.action_space.sample()
    
    def step(self, action):
        state, reward, terminal, _ = self.env.step(int(action))
        #reward = 0
        
        #if terminal:
            #if state[0] > 0.5:
                #reward = 1
            #else:
                #reward = state[0] + 0.5
         
        return state, reward, terminal
    
    
                
MC = MountainCar()
st_shape=MC.state_shape[0]
act_shape=MC.action_shape[0]

# %%
action_list = [0,1,2]
gamma =0.0
lr =0.001
num_episodes = 1000#1000
epsilon =1
epsilon_decay =0.99
memory_size =10000
batch_size=32
show=False

# %%
factor=[1,100]

# %%
memory=deque(maxlen=memory_size)
s=MC.reset()
s = s.reshape((1,-1))
s = s*factor
for _ in range(memory_size):
    a = np.random.randint(0,act_shape)
    new_s,r,d =MC.step(a)
    new_s = new_s.reshape((1,-1))
    new_s = new_s*factor
    if show:
        MC.render()
    if d:
        r=-100
        experience =(s,r,a,new_s,d)
        s=MC.reset()
        s = s.reshape((1,-1))
    else:    
        experience =(s,r,a,new_s,d)
    memory.append(experience)
    s = new_s

# %% [markdown]
# ***Model Definition***

# %% [markdown]
# Here , I have defined the model as a simple MLP neural network with 2 hidden layers of 100 nodes with ```relu``` activation function

# %%
model = Sequential()
model.add(Dense(100,activation='relu',input_shape=(st_shape,)))
model.add(Dense(100,activation='relu'))
#model.add(Dense(act_shape,activation='softmax'))
model.add(Dense(act_shape,activation='linear'))
#model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=lr),)
model.compile(loss='mse',optimizer=Adam(lr=lr),)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               300
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 10,703
# Trainable params: 10,703
# Non-trainable params: 0
# _________________________________________________________________

# %%
ep_list =[]
reward_list =[] 
index=0 
oh = OneHotEncoder(categories=[range(3)])
for ep in range(num_episodes):
    s= MC.reset()
    s=s.reshape((1,-1))
    s = s*factor
    total_rewards =0
    d = False
    j = 0
    for j in range(200):
        if np.random.random()< epsilon:
            a = np.random.randint(0,len(action_list))
        else:
            Q = model.predict(s.reshape(1,-1))
            a =np.argmax(Q)
        new_s,r,d = MC.step(a)
        new_s = new_s.reshape((1,-1))
        new_s = new_s*factor
        total_rewards=total_rewards+r
        if show:
            MC.render()
        if d:
            if total_rewards<-199:
                r =-100
                experience = (s,r,a,new_s,d)
                memory.append(experience)
                print("Episode %d, Failed! Reward %d"%(ep,total_rewards))
            elif total_rewards<-110 and total_rewards>-199:
                r=10
                d=True
                experience = (s,r,a,new_s,d)
                memory.append(experience)
                print("Episode %d, Better! Reward %d"%(ep,total_rewards))
            elif total_rewards>=-110:
                r=100
                experience = (s,r,a,new_s,d)
                memory.append(experience)

                print("Episode %d, Passed! Reward %d"%(ep,total_rewards))
            ep_list.append(ep)
            reward_list.append(total_rewards)
            break
        
        experience = (s,r,a,new_s,d)
        memory.append(experience)
        if j==199:
            print("Reward %d after full episode"%(total_rewards))
            
        s = new_s
    ind=np.random.choice(len(memory),batch_size)
    batches=np.array(memory)[ind]
    states= np.array([batch[0] for batch in batches],ndmin=3).reshape(len(batches),-1)
    rewards= np.array([batch[1] for batch in batches])
    actions= np.array([batch[2] for batch in batches])
    actions=oh.fit_transform(actions.reshape(-1,1)).toarray()
    actions = actions.reshape(-1,act_shape)
    new_states= np.array([batch[3] for batch in batches],ndmin=3).reshape(len(batches),-1)
    dones= np.array([batch[4] for batch in batches])
    Qs =model.predict(states)
    new_Qs = model.predict(new_states)
    target_Qs=rewards+gamma*(np.max(new_Qs,axis=1)*(~dones))
    Qs[actions==1]=target_Qs#.reshape(-1,)
    model.fit(states,Qs,verbose=0 )
    epsilon=epsilon*epsilon_decay
# Out:
# Episode 0, Failed! Reward -200
# Episode 1, Failed! Reward -200
# Episode 2, Failed! Reward -200
# Episode 3, Failed! Reward -200
# Episode 4, Failed! Reward -200
# Episode 5, Failed! Reward -200
# Episode 6, Failed! Reward -200
# Episode 7, Failed! Reward -200
# Episode 8, Failed! Reward -200
# Episode 9, Failed! Reward -200
# Episode 10, Failed! Reward -200
# Episode 11, Failed! Reward -200
# Episode 12, Failed! Reward -200
# Episode 13, Failed! Reward -200
# Episode 14, Failed! Reward -200
# Episode 15, Failed! Reward -200
# Episode 16, Failed! Reward -200
# Episode 17, Failed! Reward -200
# Episode 18, Failed! Reward -200
# Episode 19, Failed! Reward -200
# Episode 20, Failed! Reward -200
# Episode 21, Failed! Reward -200
# Episode 22, Failed! Reward -200
# Episode 23, Failed! Reward -200
# Episode 24, Failed! Reward -200
# Episode 25, Failed! Reward -200
# Episode 26, Failed! Reward -200
# Episode 27, Failed! Reward -200
# Episode 28, Failed! Reward -200
# Episode 29, Failed! Reward -200
# Episode 30, Failed! Reward -200
# Episode 31, Failed! Reward -200
# Episode 32, Failed! Reward -200
# Episode 33, Failed! Reward -200
# Episode 34, Failed! Reward -200
# Episode 35, Failed! Reward -200
# Episode 36, Failed! Reward -200
# Episode 37, Failed! Reward -200
# Episode 38, Failed! Reward -200
# Episode 39, Failed! Reward -200
# Episode 40, Failed! Reward -200
# Episode 41, Failed! Reward -200
# Episode 42, Failed! Reward -200
# Episode 43, Failed! Reward -200
# Episode 44, Failed! Reward -200
# Episode 45, Failed! Reward -200
# Episode 46, Failed! Reward -200
# Episode 47, Failed! Reward -200
# Episode 48, Failed! Reward -200
# Episode 49, Failed! Reward -200
# Episode 50, Failed! Reward -200
# Episode 51, Failed! Reward -200
# Episode 52, Failed! Reward -200
# Episode 53, Failed! Reward -200
# Episode 54, Failed! Reward -200
# Episode 55, Failed! Reward -200
# Episode 56, Failed! Reward -200
# Episode 57, Failed! Reward -200
# Episode 58, Failed! Reward -200
# Episode 59, Failed! Reward -200
# Episode 60, Failed! Reward -200
# Episode 61, Failed! Reward -200
# Episode 62, Failed! Reward -200
# Episode 63, Failed! Reward -200
# Episode 64, Failed! Reward -200
# Episode 65, Failed! Reward -200
# Episode 66, Failed! Reward -200
# Episode 67, Failed! Reward -200
# Episode 68, Better! Reward -168
# Episode 69, Failed! Reward -200
# Episode 70, Failed! Reward -200
# Episode 71, Failed! Reward -200
# Episode 72, Failed! Reward -200
# Episode 73, Failed! Reward -200
# Episode 74, Failed! Reward -200
# Episode 75, Better! Reward -163
# Episode 76, Better! Reward -175
# Episode 77, Better! Reward -194
# Episode 78, Better! Reward -193
# Episode 79, Failed! Reward -200
# Episode 80, Better! Reward -196
# Episode 81, Failed! Reward -200
# Episode 82, Failed! Reward -200
# Episode 83, Failed! Reward -200
# Episode 84, Better! Reward -190
# Episode 85, Failed! Reward -200
# Episode 86, Failed! Reward -200
# Episode 87, Failed! Reward -200
# Episode 88, Failed! Reward -200
# Episode 89, Failed! Reward -200
# Episode 90, Failed! Reward -200
# Episode 91, Failed! Reward -200
# Episode 92, Failed! Reward -200
# Episode 93, Failed! Reward -200
# Episode 94, Failed! Reward -200
# Episode 95, Failed! Reward -200
# Episode 96, Failed! Reward -200
# Episode 97, Failed! Reward -200
# Episode 98, Failed! Reward -200
# Episode 99, Failed! Reward -200
# Episode 100, Failed! Reward -200
# Episode 101, Failed! Reward -200
# Episode 102, Failed! Reward -200
# Episode 103, Failed! Reward -200
# Episode 104, Failed! Reward -200
# Episode 105, Failed! Reward -200
# Episode 106, Failed! Reward -200
# Episode 107, Failed! Reward -200
# Episode 108, Failed! Reward -200
# Episode 109, Failed! Reward -200
# Episode 110, Failed! Reward -200
# Episode 111, Failed! Reward -200
# Episode 112, Failed! Reward -200
# Episode 113, Failed! Reward -200
# Episode 114, Failed! Reward -200
# Episode 115, Failed! Reward -200
# Episode 116, Failed! Reward -200
# Episode 117, Failed! Reward -200
# Episode 118, Better! Reward -167
# Episode 119, Better! Reward -171
# Episode 120, Better! Reward -163
# Episode 121, Better! Reward -168
# Episode 122, Failed! Reward -200
# Episode 123, Failed! Reward -200
# Episode 124, Failed! Reward -200
# Episode 125, Better! Reward -159
# Episode 126, Better! Reward -172
# Episode 127, Failed! Reward -200
# Episode 128, Better! Reward -162
# Episode 129, Better! Reward -165
# Episode 130, Better! Reward -179
# Episode 131, Better! Reward -180
# Episode 132, Better! Reward -168
# Episode 133, Better! Reward -160
# Episode 134, Better! Reward -171
# Episode 135, Failed! Reward -200
# Episode 136, Failed! Reward -200
# Episode 137, Failed! Reward -200
# Episode 138, Failed! Reward -200
# Episode 139, Failed! Reward -200
# Episode 140, Failed! Reward -200
# Episode 141, Failed! Reward -200
# Episode 142, Failed! Reward -200
# Episode 143, Failed! Reward -200
# Episode 144, Failed! Reward -200
# Episode 145, Failed! Reward -200
# Episode 146, Failed! Reward -200
# Episode 147, Failed! Reward -200
# Episode 148, Failed! Reward -200
# Episode 149, Failed! Reward -200
# Episode 150, Failed! Reward -200
# Episode 151, Better! Reward -145
# Episode 152, Better! Reward -151
# Episode 153, Better! Reward -126
# Episode 154, Better! Reward -123
# Episode 155, Failed! Reward -200
# Episode 156, Failed! Reward -200
# Episode 157, Better! Reward -138
# Episode 158, Better! Reward -126
# Episode 159, Failed! Reward -200
# Episode 160, Better! Reward -142
# Episode 161, Better! Reward -150
# Episode 162, Failed! Reward -200
# Episode 163, Better! Reward -124
# Episode 164, Better! Reward -132
# Episode 165, Failed! Reward -200
# Episode 166, Failed! Reward -200
# Episode 167, Better! Reward -129
# Episode 168, Better! Reward -125
# Episode 169, Better! Reward -123
# Episode 170, Better! Reward -121
# Episode 171, Failed! Reward -200
# Episode 172, Better! Reward -126
# Episode 173, Better! Reward -127
# Episode 174, Better! Reward -146
# Episode 175, Better! Reward -123
# Episode 176, Better! Reward -122
# Episode 177, Failed! Reward -200
# Episode 178, Better! Reward -126
# Episode 179, Better! Reward -132
# Episode 180, Better! Reward -155
# Episode 181, Better! Reward -122
# Episode 182, Failed! Reward -200
# Episode 183, Failed! Reward -200
# Episode 184, Failed! Reward -200
# Episode 185, Better! Reward -121
# Episode 186, Better! Reward -124
# Episode 187, Failed! Reward -200
# Episode 188, Better! Reward -125
# Episode 189, Better! Reward -159
# Episode 190, Failed! Reward -200
# Episode 191, Better! Reward -123
# Episode 192, Better! Reward -121
# Episode 193, Better! Reward -158
# Episode 194, Better! Reward -122
# Episode 195, Better! Reward -165
# Episode 196, Better! Reward -160
# Episode 197, Better! Reward -155
# Episode 198, Failed! Reward -200
# Episode 199, Better! Reward -124
# Episode 200, Better! Reward -122
# Episode 201, Failed! Reward -200
# Episode 202, Better! Reward -121
# Episode 203, Failed! Reward -200
# Episode 204, Better! Reward -126
# Episode 205, Better! Reward -138
# Episode 206, Better! Reward -121
# Episode 207, Failed! Reward -200
# Episode 208, Failed! Reward -200
# Episode 209, Failed! Reward -200
# Episode 210, Better! Reward -123
# Episode 211, Failed! Reward -200
# Episode 212, Better! Reward -127
# Episode 213, Better! Reward -134
# Episode 214, Better! Reward -121
# Episode 215, Failed! Reward -200
# Episode 216, Better! Reward -120
# Episode 217, Failed! Reward -200
# Episode 218, Failed! Reward -200
# Episode 219, Better! Reward -118
# Episode 220, Better! Reward -122
# Episode 221, Better! Reward -149
# Episode 222, Better! Reward -122
# Episode 223, Failed! Reward -200
# Episode 224, Failed! Reward -200
# Episode 225, Better! Reward -132
# Episode 226, Better! Reward -126
# Episode 227, Failed! Reward -200
# Episode 228, Failed! Reward -200
# Episode 229, Better! Reward -122
# Episode 230, Failed! Reward -200
# Episode 231, Better! Reward -125
# Episode 232, Better! Reward -123
# Episode 233, Better! Reward -196
# Episode 234, Failed! Reward -200
# Episode 235, Better! Reward -143
# Episode 236, Better! Reward -120
# Episode 237, Better! Reward -121
# Episode 238, Better! Reward -128
# Episode 239, Failed! Reward -200
# Episode 240, Better! Reward -122
# Episode 241, Better! Reward -168
# Episode 242, Failed! Reward -200
# Episode 243, Better! Reward -124
# Episode 244, Better! Reward -125
# Episode 245, Better! Reward -132
# Episode 246, Failed! Reward -200
# Episode 247, Better! Reward -118
# Episode 248, Failed! Reward -200
# Episode 249, Failed! Reward -200
# Episode 250, Better! Reward -124
# Episode 251, Better! Reward -143
# Episode 252, Better! Reward -123
# Episode 253, Better! Reward -124
# Episode 254, Better! Reward -118
# Episode 255, Better! Reward -124
# Episode 256, Better! Reward -125
# Episode 257, Failed! Reward -200
# Episode 258, Failed! Reward -200
# Episode 259, Better! Reward -118
# Episode 260, Better! Reward -120
# Episode 261, Better! Reward -127
# Episode 262, Better! Reward -122
# Episode 263, Better! Reward -154
# Episode 264, Better! Reward -114
# Episode 265, Failed! Reward -200
# Episode 266, Better! Reward -120
# Episode 267, Failed! Reward -200
# Episode 268, Better! Reward -123
# Episode 269, Better! Reward -125
# Episode 270, Better! Reward -133
# Episode 271, Failed! Reward -200
# Episode 272, Better! Reward -123
# Episode 273, Failed! Reward -200
# Episode 274, Better! Reward -119
# Episode 275, Failed! Reward -200
# Episode 276, Failed! Reward -200
# Episode 277, Failed! Reward -200
# Episode 278, Failed! Reward -200
# Episode 279, Failed! Reward -200
# Episode 280, Failed! Reward -200
# Episode 281, Failed! Reward -200
# Episode 282, Failed! Reward -200
# Episode 283, Failed! Reward -200
# Episode 284, Failed! Reward -200
# Episode 285, Failed! Reward -200
# Episode 286, Failed! Reward -200
# Episode 287, Better! Reward -125
# Episode 288, Failed! Reward -200
# Episode 289, Better! Reward -129
# Episode 290, Better! Reward -125
# Episode 291, Better! Reward -117
# Episode 292, Better! Reward -147
# Episode 293, Failed! Reward -200
# Episode 294, Better! Reward -119
# Episode 295, Failed! Reward -200
# Episode 296, Better! Reward -125
# Episode 297, Better! Reward -121
# Episode 298, Better! Reward -117
# Episode 299, Better! Reward -121
# Episode 300, Failed! Reward -200
# Episode 301, Better! Reward -117
# Episode 302, Better! Reward -122
# Episode 303, Better! Reward -120
# Episode 304, Better! Reward -119
# Episode 305, Better! Reward -131
# Episode 306, Better! Reward -120
# Episode 307, Better! Reward -118
# Episode 308, Better! Reward -122
# Episode 309, Passed! Reward -88
# Episode 310, Better! Reward -114
# Episode 311, Better! Reward -117
# Episode 312, Passed! Reward -109
# Episode 313, Better! Reward -117
# Episode 314, Better! Reward -116
# Episode 315, Passed! Reward -95
# Episode 316, Better! Reward -118
# Episode 317, Better! Reward -165
# Episode 318, Better! Reward -123
# Episode 319, Better! Reward -118
# Episode 320, Better! Reward -156
# Episode 321, Better! Reward -125
# Episode 322, Better! Reward -120
# Episode 323, Passed! Reward -90
# Episode 324, Better! Reward -168
# Episode 325, Passed! Reward -91
# Episode 326, Passed! Reward -86
# Episode 327, Passed! Reward -87
# Episode 328, Better! Reward -169
# Episode 329, Passed! Reward -89
# Episode 330, Better! Reward -167
# Episode 331, Better! Reward -136
# Episode 332, Better! Reward -122
# Episode 333, Better! Reward -163
# Episode 334, Better! Reward -116
# Episode 335, Passed! Reward -89
# Episode 336, Better! Reward -119
# Episode 337, Passed! Reward -101
# Episode 338, Passed! Reward -88
# Episode 339, Better! Reward -155
# Episode 340, Better! Reward -171
# Episode 341, Better! Reward -164
# Episode 342, Better! Reward -116
# Episode 343, Better! Reward -161
# Episode 344, Better! Reward -127
# Episode 345, Better! Reward -123
# Episode 347, Better! Reward -119
# Episode 348, Better! Reward -122
# Episode 349, Better! Reward -130
# Episode 350, Failed! Reward -200
# Episode 351, Better! Reward -121
# Episode 352, Passed! Reward -99
# Episode 353, Failed! Reward -200
# Episode 354, Better! Reward -122
# Episode 355, Better! Reward -115
# Episode 356, Passed! Reward -93
# Episode 357, Better! Reward -170
# Episode 358, Better! Reward -118
# Episode 359, Better! Reward -169
# Episode 360, Better! Reward -130
# Episode 361, Better! Reward -166
# Episode 362, Better! Reward -165
# Episode 363, Failed! Reward -200
# Episode 364, Passed! Reward -110
# Episode 365, Failed! Reward -200
# Episode 366, Failed! Reward -200
# Episode 367, Better! Reward -116
# Episode 368, Better! Reward -197
# Episode 369, Failed! Reward -200
# Episode 370, Better! Reward -121
# Episode 371, Better! Reward -157
# Episode 372, Passed! Reward -100
# Episode 373, Better! Reward -178
# Episode 374, Better! Reward -121
# Episode 375, Passed! Reward -88
# Episode 376, Passed! Reward -97
# Episode 377, Passed! Reward -89
# Episode 378, Better! Reward -130
# Episode 379, Passed! Reward -87
# Episode 380, Better! Reward -118
# Episode 381, Passed! Reward -96
# Episode 382, Passed! Reward -89
# Episode 383, Passed! Reward -93
# Episode 384, Better! Reward -121
# Episode 385, Better! Reward -161
# Episode 386, Better! Reward -169
# Episode 387, Failed! Reward -200
# Episode 388, Better! Reward -122
# Episode 389, Failed! Reward -200
# Episode 390, Failed! Reward -200
# Episode 391, Better! Reward -175
# Episode 392, Better! Reward -166
# Episode 393, Better! Reward -163
# Episode 394, Better! Reward -124
# Episode 395, Failed! Reward -200
# Episode 396, Passed! Reward -88
# Episode 397, Passed! Reward -98
# Episode 398, Passed! Reward -95
# Episode 399, Better! Reward -117
# Episode 400, Better! Reward -119
# Episode 401, Better! Reward -123
# Episode 402, Passed! Reward -95
# Episode 403, Better! Reward -173
# Episode 404, Failed! Reward -200
# Episode 405, Better! Reward -124
# Episode 406, Passed! Reward -91
# Episode 407, Failed! Reward -200
# Episode 408, Passed! Reward -91
# Episode 409, Better! Reward -127
# Episode 410, Passed! Reward -94
# Episode 411, Passed! Reward -102
# Episode 412, Better! Reward -171
# Episode 413, Better! Reward -166
# Episode 414, Better! Reward -118
# Episode 415, Better! Reward -117
# Episode 416, Better! Reward -177
# Episode 417, Better! Reward -123
# Episode 418, Better! Reward -115
# Episode 419, Passed! Reward -95
# Episode 420, Better! Reward -122
# Episode 421, Passed! Reward -110
# Episode 422, Better! Reward -115
# Episode 423, Better! Reward -124
# Episode 424, Failed! Reward -200
# Episode 425, Passed! Reward -87
# Episode 426, Better! Reward -114
# Episode 427, Failed! Reward -200
# Episode 428, Better! Reward -118
# Episode 429, Better! Reward -118
# Episode 430, Better! Reward -175
# Episode 431, Better! Reward -115
# Episode 432, Passed! Reward -86
# Episode 433, Better! Reward -158
# Episode 434, Passed! Reward -93
# Episode 435, Failed! Reward -200
# Episode 436, Better! Reward -114
# Episode 437, Better! Reward -114
# Episode 438, Better! Reward -151
# Episode 439, Passed! Reward -106
# Episode 440, Better! Reward -154
# Episode 441, Better! Reward -160
# Episode 442, Passed! Reward -86
# Episode 443, Passed! Reward -91
# Episode 444, Passed! Reward -107
# Episode 445, Better! Reward -157
# Episode 446, Better! Reward -165
# Episode 447, Better! Reward -161
# Episode 448, Better! Reward -154
# Episode 449, Passed! Reward -90
# Episode 450, Better! Reward -151
# Episode 451, Better! Reward -152
# Episode 452, Passed! Reward -105
# Episode 453, Passed! Reward -90
# Episode 454, Better! Reward -152
# Episode 455, Better! Reward -153
# Episode 456, Better! Reward -157
# Episode 457, Passed! Reward -86
# Episode 458, Passed! Reward -90
# Episode 459, Better! Reward -161
# Episode 460, Better! Reward -160
# Episode 461, Better! Reward -158
# Episode 462, Passed! Reward -87
# Episode 463, Better! Reward -153
# Episode 464, Passed! Reward -88
# Episode 465, Better! Reward -157
# Episode 466, Passed! Reward -90
# Episode 467, Passed! Reward -110
# Episode 468, Better! Reward -153
# Episode 469, Better! Reward -157
# Episode 470, Better! Reward -158
# Episode 471, Passed! Reward -93
# Episode 472, Passed! Reward -87
# Episode 473, Passed! Reward -100
# Episode 474, Passed! Reward -97
# Episode 475, Passed! Reward -94
# Episode 476, Better! Reward -169
# Episode 477, Passed! Reward -90
# Episode 478, Passed! Reward -92
# Episode 479, Better! Reward -159
# Episode 480, Better! Reward -155
# Episode 481, Passed! Reward -97
# Episode 482, Better! Reward -116
# Episode 483, Passed! Reward -94
# Episode 484, Passed! Reward -90
# Episode 485, Better! Reward -119
# Episode 486, Better! Reward -115
# Episode 487, Better! Reward -113
# Episode 488, Passed! Reward -96
# Episode 489, Better! Reward -114
# Episode 490, Passed! Reward -89
# Episode 491, Better! Reward -153
# Episode 492, Better! Reward -171
# Episode 493, Better! Reward -180
# Episode 494, Better! Reward -158
# Episode 495, Better! Reward -153
# Episode 496, Better! Reward -160
# Episode 497, Passed! Reward -94
# Episode 498, Better! Reward -161
# Episode 499, Better! Reward -172
# Episode 500, Passed! Reward -100
# Episode 501, Better! Reward -153
# Episode 502, Passed! Reward -103
# Episode 503, Passed! Reward -100
# Episode 504, Better! Reward -154
# Episode 505, Better! Reward -164
# Episode 506, Better! Reward -152
# Episode 507, Passed! Reward -87
# Episode 508, Passed! Reward -104
# Episode 509, Better! Reward -156
# Episode 510, Passed! Reward -92
# Episode 511, Better! Reward -154
# Episode 512, Better! Reward -165
# Episode 513, Better! Reward -159
# Episode 514, Better! Reward -154
# Episode 515, Better! Reward -155
# Episode 516, Passed! Reward -87
# Episode 517, Passed! Reward -89
# Episode 518, Passed! Reward -86
# Episode 519, Passed! Reward -89
# Episode 520, Better! Reward -158
# Episode 521, Better! Reward -156
# Episode 522, Better! Reward -187
# Episode 523, Passed! Reward -89
# Episode 524, Better! Reward -165
# Episode 525, Passed! Reward -94
# Episode 526, Passed! Reward -89
# Episode 527, Passed! Reward -93
# Episode 528, Better! Reward -114
# Episode 529, Better! Reward -116
# Episode 530, Better! Reward -114
# Episode 531, Better! Reward -113
# Episode 532, Better! Reward -116
# Episode 533, Better! Reward -114
# Episode 534, Better! Reward -116
# Episode 535, Better! Reward -121
# Episode 536, Better! Reward -121
# Episode 537, Better! Reward -119
# Episode 538, Better! Reward -120
# Episode 539, Better! Reward -122
# Episode 540, Better! Reward -124
# Episode 541, Better! Reward -122
# Episode 542, Better! Reward -113
# Episode 543, Better! Reward -170
# Episode 544, Better! Reward -153
# Episode 545, Better! Reward -161
# Episode 546, Better! Reward -161
# Episode 547, Better! Reward -156
# Episode 548, Passed! Reward -96
# Episode 549, Better! Reward -182
# Episode 550, Passed! Reward -100
# Episode 551, Better! Reward -154
# Episode 552, Better! Reward -155
# Episode 553, Better! Reward -156
# Episode 554, Passed! Reward -104
# Episode 555, Passed! Reward -93
# Episode 556, Better! Reward -169
# Episode 557, Better! Reward -196
# Episode 558, Better! Reward -160
# Episode 559, Passed! Reward -87
# Episode 560, Passed! Reward -94
# Episode 561, Better! Reward -158
# Episode 562, Better! Reward -171
# Episode 563, Better! Reward -159
# Episode 564, Passed! Reward -96
# Episode 565, Passed! Reward -105
# Episode 566, Better! Reward -114
# Episode 567, Better! Reward -171
# Episode 568, Better! Reward -164
# Episode 569, Better! Reward -156
# Episode 570, Better! Reward -153
# Episode 571, Passed! Reward -87
# Episode 572, Better! Reward -152
# Episode 573, Better! Reward -156
# Episode 574, Passed! Reward -85
# Episode 575, Better! Reward -122
# Episode 576, Better! Reward -123
# Episode 577, Better! Reward -121
# Episode 578, Better! Reward -116
# Episode 579, Better! Reward -123
# Episode 580, Better! Reward -117
# Episode 581, Better! Reward -125
# Episode 582, Better! Reward -127
# Episode 583, Better! Reward -122
# Episode 584, Better! Reward -119
# Episode 585, Failed! Reward -200
# Episode 586, Better! Reward -113
# Episode 587, Better! Reward -125
# Episode 588, Better! Reward -124
# Episode 589, Better! Reward -120
# Episode 590, Better! Reward -125
# Episode 591, Better! Reward -119
# Episode 592, Better! Reward -122
# Episode 593, Better! Reward -121
# Episode 594, Passed! Reward -87
# Episode 595, Passed! Reward -91
# Episode 596, Passed! Reward -86
# Episode 597, Better! Reward -155
# Episode 598, Better! Reward -159
# Episode 599, Passed! Reward -87
# Episode 600, Passed! Reward -92
# Episode 601, Passed! Reward -95
# Episode 602, Passed! Reward -89
# Episode 603, Better! Reward -184
# Episode 604, Better! Reward -161
# Episode 605, Better! Reward -161
# Episode 606, Better! Reward -169
# Episode 607, Passed! Reward -98
# Episode 608, Passed! Reward -101
# Episode 609, Better! Reward -161
# Episode 610, Passed! Reward -91
# Episode 611, Better! Reward -122
# Episode 612, Better! Reward -164
# Episode 613, Passed! Reward -104
# Episode 614, Passed! Reward -92
# Episode 615, Better! Reward -158
# Episode 616, Passed! Reward -103
# Episode 617, Passed! Reward -87
# Episode 618, Better! Reward -171
# Episode 619, Better! Reward -162
# Episode 620, Better! Reward -156
# Episode 621, Better! Reward -168
# Episode 622, Better! Reward -156
# Episode 623, Better! Reward -159
# Episode 624, Passed! Reward -100
# Episode 625, Passed! Reward -94
# Episode 626, Better! Reward -123
# Episode 627, Better! Reward -123
# Episode 628, Passed! Reward -96
# Episode 629, Better! Reward -114
# Episode 630, Better! Reward -188
# Episode 631, Better! Reward -165
# Episode 632, Passed! Reward -92
# Episode 633, Passed! Reward -88
# Episode 634, Better! Reward -177
# Episode 635, Passed! Reward -86
# Episode 636, Passed! Reward -99
# Episode 637, Passed! Reward -86
# Episode 638, Better! Reward -153
# Episode 639, Better! Reward -154
# Episode 640, Better! Reward -160
# Episode 641, Better! Reward -154
# Episode 642, Passed! Reward -86
# Episode 643, Better! Reward -158
# Episode 644, Better! Reward -157
# Episode 645, Passed! Reward -92
# Episode 646, Passed! Reward -87
# Episode 647, Passed! Reward -103
# Episode 648, Better! Reward -160
# Episode 649, Better! Reward -160
# Episode 650, Better! Reward -158
# Episode 651, Better! Reward -157
# Episode 652, Passed! Reward -87
# Episode 653, Passed! Reward -99
# Episode 654, Better! Reward -159
# Episode 655, Better! Reward -186
# Episode 656, Better! Reward -141
# Episode 657, Better! Reward -165
# Episode 658, Passed! Reward -90
# Episode 659, Passed! Reward -104
# Episode 660, Passed! Reward -107
# Episode 661, Better! Reward -173
# Episode 662, Passed! Reward -89
# Episode 663, Better! Reward -164
# Episode 664, Passed! Reward -90
# Episode 665, Passed! Reward -102
# Episode 666, Better! Reward -159
# Episode 667, Better! Reward -159
# Episode 668, Better! Reward -182
# Episode 669, Passed! Reward -93
# Episode 670, Better! Reward -178
# Episode 671, Better! Reward -162
# Episode 672, Better! Reward -165
# Episode 673, Better! Reward -159
# Episode 674, Better! Reward -168
# Episode 675, Better! Reward -162
# Episode 676, Passed! Reward -90
# Episode 677, Better! Reward -162
# Episode 678, Better! Reward -158
# Episode 679, Passed! Reward -97
# Episode 680, Better! Reward -187
# Episode 681, Better! Reward -159
# Episode 682, Better! Reward -160
# Episode 683, Better! Reward -160
# Episode 684, Passed! Reward -93
# Episode 685, Passed! Reward -103
# Episode 686, Better! Reward -112
# Episode 687, Passed! Reward -95
# Episode 688, Better! Reward -162
# Episode 689, Better! Reward -173
# Episode 690, Passed! Reward -91
# Episode 691, Better! Reward -163
# Episode 692, Better! Reward -165
# Episode 693, Better! Reward -197
# Episode 694, Better! Reward -162
# Episode 695, Better! Reward -164
# Episode 696, Passed! Reward -95
# Episode 697, Better! Reward -162
# Episode 698, Better! Reward -119
# Episode 699, Better! Reward -168
# Episode 700, Passed! Reward -89
# Episode 701, Better! Reward -163
# Episode 702, Passed! Reward -92
# Episode 703, Passed! Reward -94
# Episode 704, Better! Reward -166
# Episode 705, Passed! Reward -102
# Episode 706, Better! Reward -188
# Episode 707, Better! Reward -164
# Episode 708, Better! Reward -172
# Episode 709, Better! Reward -173
# Episode 710, Passed! Reward -96
# Episode 711, Better! Reward -178
# Episode 712, Passed! Reward -104
# Episode 713, Better! Reward -125
# Episode 714, Better! Reward -165
# Episode 715, Better! Reward -164
# Episode 716, Passed! Reward -96
# Episode 717, Better! Reward -164
# Episode 718, Better! Reward -164
# Episode 719, Better! Reward -166
# Episode 720, Better! Reward -166
# Episode 721, Better! Reward -166
# Episode 722, Better! Reward -169
# Episode 723, Better! Reward -171
# Episode 724, Better! Reward -177
# Episode 725, Passed! Reward -92
# Episode 726, Better! Reward -171
# Episode 727, Failed! Reward -200
# Episode 728, Better! Reward -170
# Episode 729, Passed! Reward -96
# Episode 730, Passed! Reward -105
# Episode 731, Better! Reward -180
# Episode 732, Passed! Reward -97
# Episode 733, Better! Reward -170
# Episode 734, Better! Reward -184
# Episode 735, Failed! Reward -200
# Episode 736, Passed! Reward -99
# Episode 737, Better! Reward -168
# Episode 738, Passed! Reward -105
# Episode 739, Better! Reward -172
# Episode 740, Better! Reward -182
# Episode 741, Passed! Reward -98
# Episode 742, Passed! Reward -95
# Episode 743, Passed! Reward -94
# Episode 744, Passed! Reward -91
# Episode 745, Better! Reward -164
# Episode 746, Better! Reward -165
# Episode 747, Passed! Reward -101
# Episode 748, Failed! Reward -200
# Episode 749, Passed! Reward -99
# Episode 750, Passed! Reward -91
# Episode 751, Better! Reward -165
# Episode 752, Passed! Reward -91
# Episode 753, Failed! Reward -200
# Episode 754, Passed! Reward -109
# Episode 755, Better! Reward -168
# Episode 756, Better! Reward -177
# Episode 757, Better! Reward -171
# Episode 758, Better! Reward -178
# Episode 759, Better! Reward -179
# Episode 760, Passed! Reward -105
# Episode 761, Better! Reward -123
# Episode 762, Better! Reward -178
# Episode 763, Failed! Reward -200
# Episode 764, Better! Reward -179
# Episode 765, Failed! Reward -200
# Episode 766, Better! Reward -181
# Episode 767, Better! Reward -115
# Episode 768, Better! Reward -115
# Episode 769, Passed! Reward -109
# Episode 770, Better! Reward -144
# Episode 771, Failed! Reward -200
# Episode 772, Better! Reward -112
# Episode 773, Failed! Reward -200
# Episode 774, Better! Reward -181
# Episode 775, Failed! Reward -200
# Episode 776, Better! Reward -114
# Episode 777, Better! Reward -174
# Episode 778, Failed! Reward -200
# Episode 779, Better! Reward -182
# Episode 780, Passed! Reward -99
# Episode 781, Passed! Reward -99
# Episode 782, Failed! Reward -200
# Episode 783, Failed! Reward -200
# Episode 784, Failed! Reward -200
# Episode 785, Failed! Reward -200
# Episode 786, Failed! Reward -200
# Episode 787, Failed! Reward -200
# Episode 788, Failed! Reward -200
# Episode 789, Failed! Reward -200
# Episode 790, Failed! Reward -200
# Episode 791, Failed! Reward -200
# Episode 792, Failed! Reward -200
# Episode 793, Failed! Reward -200
# Episode 794, Better! Reward -159
# Episode 795, Better! Reward -115
# Episode 796, Passed! Reward -94
# Episode 797, Passed! Reward -92
# Episode 798, Better! Reward -161
# Episode 799, Better! Reward -121
# Episode 800, Passed! Reward -95
# Episode 801, Passed! Reward -100
# Episode 802, Passed! Reward -91
# Episode 803, Better! Reward -163
# Episode 804, Passed! Reward -106
# Episode 805, Passed! Reward -89
# Episode 806, Better! Reward -161
# Episode 807, Better! Reward -162
# Episode 808, Passed! Reward -106
# Episode 809, Better! Reward -120
# Episode 810, Better! Reward -118
# Episode 811, Better! Reward -118
# Episode 812, Better! Reward -118
# Episode 813, Better! Reward -116
# Episode 814, Better! Reward -118
# Episode 815, Better! Reward -116
# Episode 816, Better! Reward -117
# Episode 817, Better! Reward -113
# Episode 818, Better! Reward -116
# Episode 819, Better! Reward -114
# Episode 820, Better! Reward -119
# Episode 821, Better! Reward -117
# Episode 822, Better! Reward -116
# Episode 823, Better! Reward -112
# Episode 824, Better! Reward -117
# Episode 825, Better! Reward -118
# Episode 826, Better! Reward -119
# Episode 827, Better! Reward -114
# Episode 828, Better! Reward -186
# Episode 829, Better! Reward -151
# Episode 830, Passed! Reward -93
# Episode 831, Passed! Reward -109
# Episode 832, Better! Reward -158
# Episode 833, Better! Reward -159
# Episode 834, Passed! Reward -98
# Episode 835, Better! Reward -156
# Episode 836, Passed! Reward -91
# Episode 837, Passed! Reward -87
# Episode 838, Better! Reward -163
# Episode 839, Better! Reward -182
# Episode 840, Better! Reward -157
# Episode 841, Better! Reward -158
# Episode 842, Better! Reward -132
# Episode 843, Better! Reward -162
# Episode 844, Failed! Reward -200
# Episode 845, Passed! Reward -89
# Episode 846, Failed! Reward -200
# Episode 847, Passed! Reward -92
# Episode 848, Passed! Reward -105
# Episode 849, Better! Reward -167
# Episode 850, Passed! Reward -92
# Episode 851, Better! Reward -171
# Episode 852, Better! Reward -167
# Episode 853, Better! Reward -111
# Episode 854, Failed! Reward -200
# Episode 855, Failed! Reward -200
# Episode 856, Passed! Reward -109
# Episode 857, Failed! Reward -200
# Episode 858, Failed! Reward -200
# Episode 859, Failed! Reward -200
# Episode 860, Better! Reward -177
# Episode 861, Failed! Reward -200
# Episode 862, Failed! Reward -200
# Episode 863, Failed! Reward -200
# Episode 864, Failed! Reward -200
# Episode 865, Failed! Reward -200
# Episode 866, Failed! Reward -200
# Episode 867, Failed! Reward -200
# Episode 868, Passed! Reward -103
# Episode 869, Failed! Reward -200
# Episode 870, Failed! Reward -200
# Episode 871, Failed! Reward -200
# Episode 872, Passed! Reward -99
# Episode 873, Passed! Reward -101
# Episode 874, Passed! Reward -95
# Episode 875, Better! Reward -176
# Episode 876, Better! Reward -179
# Episode 877, Failed! Reward -200
# Episode 878, Failed! Reward -200
# Episode 879, Failed! Reward -200
# Episode 880, Better! Reward -178
# Episode 881, Better! Reward -164
# Episode 882, Passed! Reward -100
# Episode 883, Passed! Reward -93
# Episode 884, Passed! Reward -100
# Episode 885, Better! Reward -111
# Episode 886, Better! Reward -163
# Episode 887, Better! Reward -177
# Episode 888, Passed! Reward -92
# Episode 889, Failed! Reward -200
# Episode 890, Passed! Reward -101
# Episode 891, Better! Reward -167
# Episode 892, Better! Reward -180
# Episode 893, Passed! Reward -98
# Episode 894, Passed! Reward -92
# Episode 895, Failed! Reward -200
# Episode 896, Better! Reward -163
# Episode 897, Failed! Reward -200
# Episode 898, Passed! Reward -91
# Episode 899, Better! Reward -175
# Episode 900, Passed! Reward -104
# Episode 901, Failed! Reward -200
# Episode 902, Better! Reward -172
# Episode 903, Failed! Reward -200
# Episode 904, Passed! Reward -97
# Episode 905, Better! Reward -167
# Episode 906, Failed! Reward -200
# Episode 907, Better! Reward -159
# Episode 908, Passed! Reward -89
# Episode 909, Better! Reward -161
# Episode 910, Better! Reward -158
# Episode 911, Passed! Reward -88
# Episode 912, Better! Reward -158
# Episode 913, Better! Reward -156
# Episode 914, Better! Reward -154
# Episode 915, Better! Reward -115
# Episode 916, Passed! Reward -86
# Episode 917, Passed! Reward -86
# Episode 918, Better! Reward -114
# Episode 919, Passed! Reward -90
# Episode 920, Better! Reward -113
# Episode 921, Better! Reward -113
# Episode 922, Better! Reward -117
# Episode 923, Better! Reward -113
# Episode 924, Passed! Reward -86
# Episode 925, Better! Reward -112
# Episode 926, Better! Reward -117
# Episode 927, Better! Reward -114
# Episode 928, Better! Reward -117
# Episode 929, Better! Reward -112
# Episode 930, Passed! Reward -89
# Episode 931, Better! Reward -119
# Episode 932, Better! Reward -114
# Episode 933, Passed! Reward -92
# Episode 934, Better! Reward -117
# Episode 935, Better! Reward -116
# Episode 936, Passed! Reward -97
# Episode 937, Better! Reward -113
# Episode 938, Passed! Reward -84
# Episode 939, Better! Reward -114
# Episode 940, Better! Reward -114
# Episode 941, Better! Reward -113
# Episode 942, Better! Reward -113
# Episode 943, Better! Reward -159
# Episode 944, Passed! Reward -94
# Episode 945, Passed! Reward -94
# Episode 946, Better! Reward -112
# Episode 947, Passed! Reward -93
# Episode 948, Passed! Reward -89
# Episode 949, Passed! Reward -103
# Episode 950, Passed! Reward -86
# Episode 951, Passed! Reward -97
# Episode 952, Better! Reward -156
# Episode 953, Better! Reward -161
# Episode 954, Better! Reward -151
# Episode 955, Passed! Reward -93
# Episode 956, Passed! Reward -88
# Episode 957, Passed! Reward -85
# Episode 958, Passed! Reward -95
# Episode 959, Passed! Reward -89
# Episode 960, Passed! Reward -101
# Episode 961, Better! Reward -161
# Episode 962, Passed! Reward -89
# Episode 963, Passed! Reward -86
# Episode 964, Better! Reward -150
# Episode 965, Passed! Reward -88
# Episode 966, Better! Reward -167
# Episode 967, Passed! Reward -105
# Episode 968, Better! Reward -150
# Episode 969, Passed! Reward -89
# Episode 970, Better! Reward -154
# Episode 971, Passed! Reward -93
# Episode 972, Better! Reward -115
# Episode 973, Passed! Reward -86
# Episode 974, Better! Reward -116
# Episode 975, Better! Reward -118
# Episode 976, Better! Reward -116
# Episode 977, Better! Reward -118
# Episode 978, Better! Reward -118
# Episode 979, Better! Reward -118
# Episode 980, Better! Reward -117
# Episode 981, Better! Reward -118
# Episode 982, Better! Reward -118
# Episode 983, Better! Reward -117
# Episode 984, Better! Reward -117
# Episode 985, Better! Reward -116
# Episode 986, Better! Reward -114
# Episode 987, Better! Reward -116
# Episode 988, Better! Reward -116
# Episode 989, Better! Reward -116
# Episode 990, Better! Reward -114
# Episode 991, Better! Reward -114
# Episode 992, Better! Reward -115
# Episode 993, Better! Reward -114
# Episode 994, Better! Reward -117
# Episode 995, Better! Reward -115
# Episode 996, Better! Reward -112
# Episode 997, Better! Reward -119
# Episode 998, Better! Reward -117
# Episode 999, Better! Reward -117

# %%
plt.figure(figsize=(10,10))
plt.plot(reward_list)
plt.title("Rewards vs Episode")
plt.xlabel("Episodes")
plt.ylabel("Rewards")
plt.savefig('DQN_MC.png')

# %%
np.argmax(reward_list)
#model.save('mc_weights.h5')

# %%
import time
import cv2
env=gym.make(env_to_use)
env.seed(0)
obs=env.reset()

#os.mkdir(env_to_use+'Test')
os.mkdir(env_to_use+'Test/img/')
print(obs.shape)
i=0
while(1):
    _action= model.predict(obs.reshape(1,-1)).reshape(-1)
    obs,rew,done,info=env.step(np.argmax(_action))
    img=env.render(mode='rgb_array')
    time.sleep(0.1)
    cv2.imwrite(env_to_use+'Test/img/'+str(i)+'.jpg',img)
    i+=1
    #if done==True:
    #    break
    if i==1000:
        break
env.close()
# Out:
# (2,)

# %%
print('Maximum Reward',np.max(reward_list))
# Out:
# Maximum Reward -84.0
